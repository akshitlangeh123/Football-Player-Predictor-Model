# %% [markdown]
# ##Importing Libraries and the Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Mini Project/preprocessed_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         short_name  ...  overall  potential
# 0           0           L. Messi  ...       93         93
# 1           1  Cristiano Ronaldo  ...       92         92
# 2           2           J. Oblak  ...       91         93
# 3           3     R. Lewandowski  ...       91         91
# 4           4          Neymar Jr  ...       91         91
#
# [5 rows x 59 columns]

# %%
nr = df.columns[[0,2,3]]

# %%
df.drop(nr,axis=1,inplace=True)

# %%
df.head()
# Out:
#           short_name  preferred_foot  ...  overall  potential
# 0           L. Messi               0  ...       93         93
# 1  Cristiano Ronaldo               1  ...       92         92
# 2           J. Oblak               1  ...       91         93
# 3     R. Lewandowski               1  ...       91         91
# 4          Neymar Jr               1  ...       91         91
#
# [5 rows x 56 columns]

# %%
df.shape
# Out:
# (18719, 56)

# %%
df.work_rate.unique()
# Out:
# array([7, 1, 8, 2, 0, 6, 3, 5, 4])

# %%
df.team_position.unique()
# Out:
# array([ 0, 13,  5, 27, 14, 19,  8, 25, 28,  3,  2, 20, 24,  9, 17,  7, 12,
#        18, 11,  1, 23, 10, 22, 21, 15,  4,  6, 26, 16])

# %%
df.preferred_foot.unique()
# Out:
# array([0, 1])

# %% [markdown]
# ##Traing Model

# %%
X1 = df.iloc[:,1:53].values
X2 = df.iloc[:,2:53].values
X3 = df.iloc[:,2:53].values
y1 = df.iloc[:,53].values
y2 = df.iloc[:,54].values
y3 = df.iloc[:,55].values

# %%
print(y2)
# Out:
# [93 92 91 ... 47 47 47]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X1 = sc.fit_transform(X1)
X2 = sc.fit_transform(X2)
X3 = sc.fit_transform(X3)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='rbf',random_state=0)
classifier.fit(X1,y1)
# Out:
# SVC(random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 1)
X2_poly = poly_reg.fit_transform(X2)
lin_reg = LinearRegression()
regressor1 = lin_reg.fit(X2_poly,y2)

# %%
poly_reg_ = PolynomialFeatures(degree = 1)
X3_poly = poly_reg_.fit_transform(X3)
lin_reg = LinearRegression()
regressor2 = lin_reg.fit(X3_poly,y3)

# %% [markdown]
# ##Importing the Non-Professional Player dataset

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Mini Project/non-professional - non-professional.csv")
df2.head()
# Out:
#             short_name preferred_foot  ... overall  potential
# 0       Ilias Akhomach           Left  ...     NaN        NaN
# 1              Ez Abde          Right  ...     NaN        NaN
# 2      Matheus Pereira           Left  ...     NaN        NaN
# 3  Maarten Vandevoordt          Right  ...     NaN        NaN
# 4        M Morgenstern          Right  ...     NaN        NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# ##Encoding the Categorical Data

# %%
objList = df2.select_dtypes(include = "object").columns
print (objList)
# Out:
# Index(['short_name', 'preferred_foot', 'team_position', 'work_rate'], dtype='object')

# %%
a = {'Medium/Low':7, 'High/Low':1, 'Medium/Medium':8, 'High/Medium':2,
       'High/High':0, 'Medium/High':6, 'Low/High':3, 'Low/Medium':5, 'Low/Low':4}
b = {'CAM':0, 'LS':13, 'GK':5, 'ST':27, 'LW':14, 'RCM':19, 'LCB':8, 'RW':25, 'SUB':28, 'CF':3,
       'CDM':2, 'RDM':20, 'RS':24, 'LCM':9, 'RB':17, 'LB':7, 'LM':12, 'RCB':18, 'LF':11, 'CB':1,
       'RM':23, 'LDM':10, 'RF':22, 'RES':21, 'LWB':15, 'CM':4, 'LAM':6, 'RWB':26, 'RAM':16}
c = {'Left':0,'Right':1}
df2['work_rate'] = df2['work_rate'].map(a)
df2['team_position'] = df2['team_position'].map(b)
df2['preferred_foot'] = df2['preferred_foot'].map(c)

# %%
df2
# Out:
#             short_name  preferred_foot  ...  overall  potential
# 0       Ilias Akhomach               0  ...      NaN        NaN
# 1              Ez Abde               1  ...      NaN        NaN
# 2      Matheus Pereira               0  ...      NaN        NaN
# 3  Maarten Vandevoordt               1  ...      NaN        NaN
# 4        M Morgenstern               1  ...      NaN        NaN
# 5              V dican               1  ...      NaN        NaN
# 6              J seelt               0  ...      NaN        NaN
# 7             L Stanga               1  ...      NaN        NaN
# 8          Manu Martos               0  ...      NaN        NaN
#
# [9 rows x 56 columns]

# %% [markdown]
# ##Predicting the Result

# %%
df2.columns.get_loc('player_positions')
# Out:
# 53

# %%
X1_ = df2.iloc[:,1:53].values
X2_ = df2.iloc[:,2:53].values

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X1_ = sc.fit_transform(X1_)
X2_ = sc.fit_transform(X2_)

# %%
y1_pred = classifier.predict(X1_)

# %%
df2['player_positions'][0]

# %%
for i in range(len(y1_pred)):
  df2['player_positions'][i] = y1_pred[i]

# %%
df2.head()

# %%
y_pred = regressor1.predict(poly_reg.fit_transform(X2_))

# %%
print(y_pred)
# Out:
# [72.21169788 77.52086023 78.62027794 69.43132286 78.38848478 46.51624409
#  59.93552346 60.68449262 47.4063053 ]

# %%
y_pred2 = regressor2.predict(poly_reg_.fit_transform(X2_))

# %%
print(y_pred2)
# Out:
# [85.15480786 82.98063232 77.02212705 74.50161017 87.01374047 50.62254516
#  70.77798956 66.74304217 44.9907599 ]
